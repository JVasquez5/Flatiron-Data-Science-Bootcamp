# %% [markdown]
# # Final Project Submission
#
# * Student name: Jonathan Vasquez
# * Student pace: Full Time
# * Scheduled project review date/time:
# * Instructor name: Fangfang Lee, SeanAbu Wilson, Matthew Wasserman
# * Blog post URL:

# %% [markdown]
# # Importing Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import os, shutil
import tensorflow as tf
import seaborn as sns
import pandas as pd
import cv2
import glob
import random
import keras
import PIL.Image
import matplotlib.image as mpimg
import re

from keras import models, layers
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.layers import Dense, Dropout, Flatten, ZeroPadding2D
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical 
from keras.optimizers import Adam, SGD, RMSprop 
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications import vgg16
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions
from keras.applications.vgg16 import VGG16

from IPython.display import display
from random import randint
from pathlib import Path
from PIL import Image
from glob import glob 
import splitfolders 

from bokeh.models import ColumnDataSource, HoverTool, Panel, FactorRange
from bokeh.plotting import figure
from bokeh.io import output_notebook, show, output_file
from bokeh.palettes import Spectral6

from sklearn.metrics import confusion_matrix, f1_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, f1_score

np.random.seed(123)

# %% [markdown]
# # Importing Data

# %%
#Setting the Base Directory
root_dir = "mol_images/"
root_dir
# Out:
# 'mol_images/'

# %%
##Converting PNG to JPG. NO NEED TO RUN AGAIN
#images_shape = []
#for k, image_path in enumerate(glob(root_dir + "*/*")):
#    im = Image.open(image_path)
#    rgb_im = im.convert('RGB')
#    rgb_im.save(image_path.replace("png", "jpg"), quality=95)

# %%
##Split with a ratio. NO NEED TO RUN AGAIN
#splitfolders.ratio(root_dir, output="output", seed=1337, 
#                   ratio=(.8, .1, .1), group_prefix=None) # default values

# %%
train_dir = os.path.join(root_dir, "train/")
test_dir = os.path.join(root_dir, "test/")
val_dir = os.path.join(root_dir, "val/")

# %%
# glob data together to get TOXIC and NOT_TOXIC images
toxic = glob(train_dir + "toxic/*")
not_toxic = glob(test_dir + "not_toxic/*")

# %%
# extract 6 random images from NOT_TOXIC
random_images = [not_toxic[i] for i in range(6)]

print('Display NOT_TOXIC Images')

# adjust the size of the images
plt.figure(figsize=(10,8))

# iterate and plot random images
for i in range(6):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(random_images[i])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    
# adjust subplot parameters to give specified padding
plt.tight_layout()
# Out:
# Display NOT_TOXIC Images

# %%
# extract 6 random images from TOXIC
random_images = [toxic[i] for i in range(10)]

print('Display TOXIC Images')

# adjust the size of the images
plt.figure(figsize=(10,8))

# iterate and plot random images
for i in range(6):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(random_images[i])
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    
# adjust subplot parameters to give specified padding
plt.tight_layout()
# Out:
# Display TOXIC Images

# %% [markdown]
# # EDA/Data Cleaning

# %%
# let's find out how many images we have in each folder
print("Number of images in Train is {}".format(len(glob(train_dir + "*/*"))))
print("Number of images in Test is {}".format(len(glob(test_dir + "*/*"))))
print("Number of images in Validation is {}".format(len(glob(val_dir + "*/*"))))
# Out:
# Number of images in Train is 11199
# Number of images in Test is 1387
# Number of images in Validation is 1395

# %%
# time to check the distribution of images within each category
Categories = ["Train", "Test", "Validation"]
Subcategories = ['TOXIC', 'NOT_TOXIC']

Train = [5635, 690]
Test = [5564, 697]
Validation = [700, 695]

data = {'Categories':Categories,
        'Train':Train,
        'Test':Test,
        'Validation':Validation}

x = [(categories, subcategories) 
     for categories in Categories for subcategories in Subcategories]
counts = sum(zip(data['Train'], data['Test'], data['Validation']), ())

source = ColumnDataSource(data=dict(x=x, counts=counts, color=Spectral6))

p = figure(x_range=FactorRange(*x), 
           plot_height=600, 
           plot_width=1000, title="Distribution of images with different category",
           tools="hover, pan, box_zoom, wheel_zoom, reset, save", tooltips= ("@x: @counts"))

p.vbar(x='x', top='counts', width=0.9, color='color', legend_field="x", source=source)

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"
output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1048">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="bea4ced8-8910-4b50-bc6f-b3fb76614b33" data-root-id="1003"></div>

# %% [markdown]
# # Data Processing/Data Augmentation

# %%
# image preprocessing
train_datagen = ImageDataGenerator(rotation_range = 30,
                                   width_shift_range = 0.1,
                                   height_shift_range = 0.1,
                                   horizontal_flip = True,  
                                   # horizontal flip added to ensure proper learning
                                   rescale = 1./255)
val_datagen = ImageDataGenerator(rescale = 1./255)
test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
# creation of training, validation, and test sets, including augmentation for the training set
batch_size = 16
training_set = train_datagen.flow_from_directory(train_dir,
                                                 target_size = (300, 300), 
                                                 batch_size = batch_size, 
                                                 class_mode = "binary") 
                                            #binary class because either toxic or not toxic
val_set = val_datagen.flow_from_directory(val_dir,
                                          target_size = (300, 300),
                                          batch_size = batch_size,
                                          class_mode = 'binary')
test_set = test_datagen.flow_from_directory(test_dir,
                                            target_size = (300, 300),
                                            batch_size = batch_size,
                                            class_mode = 'binary')
# Out:
# Found 11199 images belonging to 2 classes.
# Found 1395 images belonging to 2 classes.
# Found 1387 images belonging to 2 classes.

# %% [markdown]
# # Base CNN

# %%
# vanilla CNN consisting of 2 Zero Padding layers, 2 Convolutional layers, 2 Pooling layers, 
# Flatten, 2 Dense, 2 Dropout, & Output layer
cnn = models.Sequential()
cnn.add(ZeroPadding2D((1,1),input_shape=(300,300,3)))
cnn.add(layers.Conv2D(64, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(ZeroPadding2D((1,1)))
cnn.add(layers.Conv2D(32, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Flatten())
cnn.add(layers.Dense(32, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(layers.Dense(32, activation='relu'))
cnn.add(Dropout(0.5))
cnn.add(layers.Dense(1, activation='sigmoid'))

# set variable for learning rate so that it can be tuned
optimizer = Adam(lr = 0.001)

cnn.compile(loss='binary_crossentropy', optimizer=optimizer, 
            metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
                     tf.keras.metrics.Recall(name='recall')])

# %%
cnn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 302, 302, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 300, 300, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 150, 150, 64)      0
# _________________________________________________________________
# zero_padding2d_1 (ZeroPaddin (None, 152, 152, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 32)      18464
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 75, 75, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 180000)            0
# _________________________________________________________________
# dense (Dense)                (None, 32)                5760032
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 5,781,377
# Trainable params: 5,781,377
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Initial CNN

# %%
cnn1 = cnn.fit(training_set, 
               epochs=10, 
               workers=-1, 
               validation_data=val_set, 
               shuffle=True)
# Out:
# Epoch 1/10
# 700/700 [==============================] - 1167s 2s/step - loss: 0.6432 - accuracy: 0.6535 - precision: 0.6961 - recall: 0.5528 - val_loss: 0.6797 - val_accuracy: 0.6301 - val_precision: 0.7447 - val_recall: 0.4000
# Epoch 2/10
# 700/700 [==============================] - 1004s 1s/step - loss: 0.5668 - accuracy: 0.7339 - precision: 0.8670 - recall: 0.5565 - val_loss: 0.6789 - val_accuracy: 0.5943 - val_precision: 0.6573 - val_recall: 0.4000
# Epoch 3/10
# 700/700 [==============================] - 869s 1s/step - loss: 0.5643 - accuracy: 0.7346 - precision: 0.8552 - recall: 0.5689 - val_loss: 0.6415 - val_accuracy: 0.6115 - val_precision: 0.7724 - val_recall: 0.3200
# Epoch 4/10
# 700/700 [==============================] - 852s 1s/step - loss: 0.5492 - accuracy: 0.7401 - precision: 0.8588 - recall: 0.5785 - val_loss: 0.6488 - val_accuracy: 0.6251 - val_precision: 0.7311 - val_recall: 0.4000
# Epoch 5/10
# 700/700 [==============================] - 861s 1s/step - loss: 0.5391 - accuracy: 0.7427 - precision: 0.8575 - recall: 0.5862 - val_loss: 0.6262 - val_accuracy: 0.6287 - val_precision: 0.7826 - val_recall: 0.3600
# Epoch 6/10
# 700/700 [==============================] - 896s 1s/step - loss: 0.5423 - accuracy: 0.7416 - precision: 0.8576 - recall: 0.5833 - val_loss: 0.6226 - val_accuracy: 0.6516 - val_precision: 0.7662 - val_recall: 0.4400
# Epoch 7/10
# 700/700 [==============================] - 906s 1s/step - loss: 0.5407 - accuracy: 0.7415 - precision: 0.8624 - recall: 0.5785 - val_loss: 0.6285 - val_accuracy: 0.6502 - val_precision: 0.7624 - val_recall: 0.4400
# Epoch 8/10
# 700/700 [==============================] - 862s 1s/step - loss: 0.5408 - accuracy: 0.7422 - precision: 0.8668 - recall: 0.5762 - val_loss: 0.6186 - val_accuracy: 0.6573 - val_precision: 0.7817 - val_recall: 0.4400
# Epoch 9/10
# 700/700 [==============================] - 839s 1s/step - loss: 0.5318 - accuracy: 0.7452 - precision: 0.8641 - recall: 0.5858 - val_loss: 0.6133 - val_accuracy: 0.6452 - val_precision: 0.7887 - val_recall: 0.4000
# Epoch 10/10
# 700/700 [==============================] - 862s 1s/step - loss: 0.5336 - accuracy: 0.7427 - precision: 0.8680 - recall: 0.5764 - val_loss: 0.6131 - val_accuracy: 0.6473 - val_precision: 0.7955 - val_recall: 0.4000

# %%
# visualization of loss and accuracy over the 50 epochs
hist_cnn = cnn1.history
loss_values = hist_cnn['loss']
val_loss_values = hist_cnn['val_loss']
acc_values = hist_cnn['accuracy'] 
val_acc_values = hist_cnn['val_accuracy']


epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(15,4))
plt.subplot(121)
plt.plot(epochs, loss_values, 'g.', label='Training loss')
plt.plot(epochs, val_loss_values, 'g', label='Validation loss')

plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(122)
plt.plot(epochs, acc_values, 'r.', label='Training acc')
plt.plot(epochs, val_acc_values, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Base Model Results

# %%
test_accu = cnn.evaluate(test_set)
# Out:
# 87/87 [==============================] - 22s 251ms/step - loss: 0.5473 - accuracy: 0.7282 - precision: 0.8337 - recall: 0.5667

# %%
print('The testing accuracy is :',test_accu[1]*100, '%')
# Out:
# The testing accuracy is : 72.81903624534607 %

# %%
# extract 9 random images from the test set
imageset = glob(test_dir + "*/*")
random_images = [np.random.choice(imageset) for i in range(9)]

print('Here are the actual classes for each image')
print(random_images)
print('Below are the predictions')

# adjust the size of the images
plt.figure(figsize=(10,8))

# iterate and plot random images
for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = cv2.imread(random_images[i])
    orig = img.copy()
    img = cv2.resize(img, (300,300))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img/255
    prediction = cnn.predict(img)
    
    if (prediction < 0.5):
        plt.title("NOT_TOXIC", fontdict = {'fontsize' : 30})
    
    else:
        plt.title("TOXIC", fontdict = {'fontsize' : 30})
    plt.imshow(orig, cmap='gray')
    plt.axis('off')
    
# adjust subplot parameters to give specified padding
plt.tight_layout()
# Out:
# Here are the actual classes for each image
# ['mol_images/test/toxic/TOX3679 copy.jpg', 'mol_images/test/toxic/TOX4662 copy 20.jpg', 'mol_images/test/toxic/TOX27006 copy 21.jpg', 'mol_images/test/not_toxic/TOX21356.jpg', 'mol_images/test/not_toxic/TOX5474.jpg', 'mol_images/test/toxic/TOX26892 copy 18.jpg', 'mol_images/test/not_toxic/TOX28947.jpg', 'mol_images/test/not_toxic/TOX25989.jpg', 'mol_images/test/not_toxic/TOX6619.jpg']
# Below are the predictions

# %% [markdown]
# # Transfer Learning - VGG16

# %%
# setting image size
img_rows, img_cols = 300, 300

vgg16_model = vgg16.VGG16(weights= 'imagenet', 
                    include_top=False, 
                    input_shape=(img_rows, img_cols, 3))

# %%
# freezing the layers 
for layer in vgg16_model.layers:
    layer.trainable = False

# %%
vgg16_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300, 300, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 300, 300, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 300, 300, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 150, 150, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 150, 150, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 150, 150, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 75, 75, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 75, 75, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 75, 75, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 75, 75, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 37, 37, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 37, 37, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 18, 18, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
# adding additional layers for hyperparameter tuning
def layer_adder(bottom_model, num_classes):
    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024, activation='relu')(top_model)
    top_model = Dense(512, activation='relu')(top_model)
    top_model = Dense(1, activation='sigmoid')(top_model)
    return top_model

# %%
# pulling together the entire model
num_classes = 2

FC_Head = layer_adder(vgg16_model, num_classes)

vgg16_model = Model(inputs = vgg16_model.input, outputs = FC_Head)

print(vgg16_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 300, 300, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 300, 300, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 300, 300, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 150, 150, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 150, 150, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 150, 150, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 75, 75, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 75, 75, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 75, 75, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 75, 75, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 37, 37, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 37, 37, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 37, 37, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 18, 18, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 18, 18, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 9, 9, 512)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dense_4 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 15,765,313
# Trainable params: 1,050,625
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %% [markdown]
# # Fitting the Model

# %% [markdown]
# 27 total epochs

# %%
checkpoint = ModelCheckpoint('face_detector.h15', 
                             monitor = 'val_loss', 
                             mode = 'min', 
                             save_best_only = True, 
                             verbose = 1)
earlystop = EarlyStopping(monitor='val_loss', 
                          min_delta = 0, 
                          patience = 3, 
                          verbose = 1, 
                          restore_best_weights= True)
callbacks = [earlystop, checkpoint]

vgg16_model.compile(loss = 'binary_crossentropy', 
              optimizer = 'Adam', 
              metrics=['accuracy',tf.keras.metrics.Precision(name='precision'),
                     tf.keras.metrics.Recall(name='recall')])

nb_train_samples = 11199
nb_validation_samples = 1395

epochs = 25
batch_size = 16

history = vgg16_model.fit_generator(training_set,
                                    epochs=epochs,
                                    callbacks = callbacks,
                                    validation_data= val_set)
# Out:
# Epoch 1/25
# 700/700 [==============================] - ETA: 0s - loss: 0.3460 - accuracy: 0.8231 - precision: 0.8338 - recall: 0.8099
# Epoch 00001: val_loss improved from inf to 1.75261, saving model to face_detector.h15
# INFO:tensorflow:Assets written to: face_detector.h15/assets
# 700/700 [==============================] - 2873s 4s/step - loss: 0.3460 - accuracy: 0.8231 - precision: 0.8338 - recall: 0.8099 - val_loss: 1.7526 - val_accuracy: 0.6545 - val_precision: 0.8811 - val_recall: 0.3600
# Epoch 2/25
# 700/700 [==============================] - ETA: 0s - loss: 0.3479 - accuracy: 0.8188 - precision: 0.8283 - recall: 0.8073
# Epoch 00002: val_loss improved from 1.75261 to 1.29590, saving model to face_detector.h15
# INFO:tensorflow:Assets written to: face_detector.h15/assets
# 700/700 [==============================] - 2762s 4s/step - loss: 0.3479 - accuracy: 0.8188 - precision: 0.8283 - recall: 0.8073 - val_loss: 1.2959 - val_accuracy: 0.6287 - val_precision: 0.8421 - val_recall: 0.3200
# Epoch 3/25
# 700/700 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.8291 - precision: 0.8329 - recall: 0.8261
# Epoch 00003: val_loss did not improve from 1.29590
# 700/700 [==============================] - 2640s 4s/step - loss: 0.3303 - accuracy: 0.8291 - precision: 0.8329 - recall: 0.8261 - val_loss: 1.4098 - val_accuracy: 0.6272 - val_precision: 0.7368 - val_recall: 0.4000
# Epoch 4/25
# 700/700 [==============================] - ETA: 0s - loss: 0.3204 - accuracy: 0.8370 - precision: 0.8413 - recall: 0.8334
# Epoch 00004: val_loss did not improve from 1.29590
# 700/700 [==============================] - 2610s 4s/step - loss: 0.3204 - accuracy: 0.8370 - precision: 0.8413 - recall: 0.8334 - val_loss: 1.6726 - val_accuracy: 0.6237 - val_precision: 0.7273 - val_recall: 0.4000
# Epoch 5/25
# 700/700 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.8428 - precision: 0.8433 - recall: 0.8445Restoring model weights from the end of the best epoch.
#
# Epoch 00005: val_loss did not improve from 1.29590
# 700/700 [==============================] - 2648s 4s/step - loss: 0.3174 - accuracy: 0.8428 - precision: 0.8433 - recall: 0.8445 - val_loss: 1.5372 - val_accuracy: 0.6244 - val_precision: 0.7683 - val_recall: 0.3600
# Epoch 00005: early stopping

# %% [markdown]
# # Transfer Learning Model Results

# %%
test_accu = vgg16_model.evaluate(test_set)
# Out:
# 87/87 [==============================] - 283s 3s/step - loss: 0.7847 - accuracy: 0.6857 - precision: 0.8692 - recall: 0.4333

# %%
print('The testing accuracy is :',test_accu[1]*100, '%')
# Out:
# The testing accuracy is : 68.5652494430542 %

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()

#summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='best')
plt.show()

# %%
# extract 9 random images from the test set
imageset = glob(test_dir + "*/*")
random_images = [np.random.choice(imageset) for i in range(9)]

print('Here are the actual classes for each image')
print(random_images)
print('Below are the predictions')

# adjust the size of your images
plt.figure(figsize=(10,8))

# iterate and plot random images
for i in range(9):
    plt.subplot(3, 3, i + 1)
    img = cv2.imread(random_images[i])
    orig = img.copy()
    img = cv2.resize(img, (300,300))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = img/255
    prediction = vgg16_model.predict(img)
    
    if (prediction < 0.5):
        plt.title("NOT_TOXIC", fontdict = {'fontsize' : 30})
    
    else:
        plt.title("TOXIC", fontdict = {'fontsize' : 30})
    plt.imshow(orig, cmap='gray')
    plt.axis('off')
    
# adjust subplot parameters to give specified padding
plt.tight_layout()
# Out:
# Here are the actual classes for each image
# ['mol_images/test/toxic/TOX26892 copy 21.jpg', 'mol_images/test/not_toxic/TOX26161.jpg', 'mol_images/test/toxic/TOX11980 copy 12.jpg', 'mol_images/test/not_toxic/TOX14576.jpg', 'mol_images/test/toxic/TOX3276 copy 20.jpg', 'mol_images/test/toxic/TOX260 copy 15.jpg', 'mol_images/test/not_toxic/TOX20579.jpg', 'mol_images/test/toxic/TOX260 copy 17.jpg', 'mol_images/test/not_toxic/TOX25989.jpg']
# Below are the predictions
